# %%
import os
from dotenv import load_dotenv
load_dotenv()

os.environ["OPENAI_API_KEY"]=os.getenv("OPENAI_API_KEY")
os.environ["GOOGLE_API_KEY"]=os.getenv("GOOGLE_API_KEY")
os.environ["GROQ_API_KEY"]=os.getenv("GROQ_API_KEY")

# %%
import os
from dotenv import load_dotenv
load_dotenv()

os.environ["OPENAI_API_KEY"]=os.getenv("OPENAI_API_KEY")
os.environ["GOOGLE_API_KEY"]=os.getenv("GOOGLE_API_KEY")
os.environ["GROQ_API_KEY"]=os.getenv("GROQ_API_KEY")
# Out:
# ChatOpenAI(metadata={'lc_versions': {'langchain-core': '1.4.8', 'langchain': '1.3.10', 'langchain-openai': '1.3.2'}}, output_version=None, profile={'name': 'GPT-4.1', 'release_date': '2025-04-14', 'last_updated': '2025-04-14', 'open_weights': False, 'max_input_tokens': 1047576, 'max_output_tokens': 32768, 'text_inputs': True, 'image_inputs': True, 'audio_inputs': False, 'pdf_inputs': True, 'video_inputs': False, 'text_outputs': True, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': False, 'tool_calling': True, 'structured_output': True, 'attachment': True, 'temperature': True, 'image_url_inputs': True, 'pdf_tool_message': True, 'image_tool_message': True, 'tool_choice': True, 'tool_call_streaming': True}, client=<openai.resources.chat.completions.completions.Completions object at 0x112349eb0>, async_client=<openai.resources.chat.completions.completions.AsyncCompletions object at 0x11265d190>, root_client=<openai.OpenAI object at 0x1118173b0>, root_async_client=<openai.AsyncOpenAI object at 0x1122d7380>, model_name='gpt-4.1', model_kwargs={}, openai_api_key=SecretStr('**********'), openai_proxy=None, stream_usage=True, stream_chunk_timeout=120.0)

# %%
## invoke the model
response=model.invoke("Hello How are you?")
response
# Out:
# AIMessage(content="Hello! I'm just a computer program, so I don't have feelings, but I'm here and ready to help you. How can I assist you today?", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 30, 'prompt_tokens': 12, 'total_tokens': 42, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4.1-2025-04-14', 'system_fingerprint': 'fp_782482fbba', 'id': 'chatcmpl-E87IfKqR5IZOCHGrjlmAMCsBYmLJm', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019fbe41-87d3-7b82-be63-50966dc7d511-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 12, 'output_tokens': 30, 'total_tokens': 42, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %%
### ChatOpenAI

from langchain_openai import ChatOpenAI
model=ChatOpenAI(model="gpt-4.1")
response=model.invoke("Hello How are you?")
response
# Out:
# AIMessage(content="Hello! I'm an AI, so I don't have feelings, but I'm here and ready to help you. How can I assist you today?", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 28, 'prompt_tokens': 12, 'total_tokens': 40, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4.1-2025-04-14', 'system_fingerprint': 'fp_782482fbba', 'id': 'chatcmpl-E87IvnF2rhaCe84O4S2h6krwOowMR', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019fbe41-c5b5-7432-b4f2-de3e1764252f-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 12, 'output_tokens': 28, 'total_tokens': 40, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %%
response.content
# Out:
# "Hello! I'm an AI, so I don't have feelings, but I'm here and ready to help you. How can I assist you today?"

# %% [markdown]
# Google Gemini Model Integration

# %%
import os
from langchain.chat_models import init_chat_model

os.environ["GOOGLE_API_KEY"] = os.getenv("GOOGLE_API_KEY")

model = init_chat_model("google_genai:gemini-3.6-flash")
response = model.invoke("Why do parrots talk?")
response.content
# Out:
# [{'type': 'text',
#   'text': 'Parrots talk—or more accurately, mimic human speech—because of a unique combination of **social instincts, specialized brain anatomy, and physical capabilities**. \n\nHere is a breakdown of why and how they do it:\n\n---\n\n### 1. Social Instincts and the "Flock"\nParrots are highly social creatures that live in complex groups (flocks). In the wild, members of a flock use distinct calls to communicate, identify each other, and coordinate group movement. \n\n* **Fitting In:** When a parrot lives in a human home, **you and your family become its flock**. \n* **Adapting to the Environment:** Parrots want to fit in and communicate with their flock members. Since humans don\'t speak "parrot," the bird learns to speak "human" to connect, seek attention, and build a bond.\n\n### 2. Specialized Brain Structure\nNot all birds can mimic sounds. Parrots, songbirds, and hummingbirds are the only bird groups capable of "vocal learning." However, parrots are exceptionally good at it.\n\n* Scientists discovered that parrot brains have specialized "song centers" that control vocal learning.\n* Uniquely, parrots have a **"shell" layer** around these brain centers that other vocal-learning birds do not have. This shell plays a major role in their ability to process complex sounds and copy speech so accurately.\n\n### 3. Unique Physical Anatomy (The Syrinx)\nHumans produce speech using vocal cords in the larynx and shape words using the lips and tongue. Parrots do not have vocal cords. Instead, they use a vocal organ called the **syrinx**, located at the base of their trachea (windpipe).\n\n* By manipulating the muscles surrounding the syrinx and controlling the airflow from their lungs, parrots can produce a astonishing range of sounds.\n* They also use their **thick, fleshy tongues** and beak movements to shape the sounds into recognizable human words and tones.\n\n### 4. Positive Reinforcement and Attention\nParrots are very smart and quickly figure out cause and effect. \n* If a parrot says "Hello!" or whistles, its human companion usually turns around, talks back, laughs, or gives it a treat. \n* Because parrots love attention, they will repeat words and phrases that get a big reaction from their owners.\n\n### 5. Do they actually know what they are saying?\nIt depends. Most of the time, parrots engage in **contextual association**. For example, they might say "Good morning!" when you enter the room in the morning, not because they understand the concept of time, but because they associate that phrase with you opening their cage.\n\nHowever, some species—like the **African Grey Parrot**—are capable of higher-level cognitive association. Famous research with an African Grey named Alex showed that parrots can use human words to correctly identify colors, shapes, quantities, and even concepts like "same" or "different."\n\n---\n\n### Summary\nIn short, **parrots talk because they are biologically equipped to learn complex sounds, and psychologically wired to use those sounds to connect with their "flock"—which, in captivity, is us.**',
#   'extras': {'signature': '...'}}]

# %%
import os
from langchain_google_genai import ChatGoogleGenerativeAI



model = ChatGoogleGenerativeAI(model="gemini-3.6-flash")
response = model.invoke("Why do parrots talk?")
response
# Out:
# AIMessage(content=[{'type': 'text', 'text': 'Parrots "talk" primarily because they are **highly social animals**, **vocal learners**, and natural **mimics**. In the wild, they use sound to bond with their flock, but in captivity, humans become their flock—so they mimic human speech to fit in.\n\nHere is a deeper look at the physical, social, and evolutionary reasons why parrots talk:\n\n---\n\n### 1. The Need to Fit In (The "Flock" Mentality)\nIn the wild, parrots live in complex, highly social groups. \n* **Flock Dialects:** Different parrot flocks actually have distinct "dialects." Young parrots learn the specific calls of their group to identify friends, signal danger, and stay connected in dense jungles.\n* **Human as the Flock:** When a parrot is kept as a pet, it views its human family as its flock. Because parrots want to bond and communicate with their group, they naturally try to imitate the sounds their "flock" makes—which happens to be human words, laughter, or the ring of a cell phone.\n\n### 2. Rare Brain Structure (Vocal Learners)\nParrots are among a very small group of animals capable of "vocal learning"—the ability to hear a sound and reproduce it. \n* Scientists have discovered that parrot brains have a unique structure. While other vocal-learning birds (like songbirds) have specific "cores" in their brains that control vocal learning, parrots also have **"shells"**—outer rings surrounding these cores. \n* These additional brain regions give parrots superior motor control, allowing them to imitate complex sounds and even dance to a rhythm.\n\n### 3. Unique Physical Anatomy (How They Do It)\nParrots do not have lips or teeth, and they don\'t have vocal cords like humans do. Instead, they produce human-like speech using:\n* **The Syrinx:** Located at the base of the trachea (windpipe), this organ acts like a voice box. By altering the air pressure passing through the syrinx, parrots can create a vast range of pitch and tone.\n* **A Muscular Tongue:** Parrots have thick, fleshy tongues that they use to shape the vibrations coming from the syrinx, allowing them to mimic human consonants (like *p*, *b*, *t*, and *d*) surprisingly well.\n\n### 4. Attention and Positive Reinforcement\nParrots are extremely intelligent and thrive on attention. \n* When a parrot makes a noise that sounds like a human word, humans usually react enthusiastically—they turn around, smile, talk back, or offer a treat. \n* Parrots quickly learn that "talking" is a great way to get immediate attention and rewards from their owners.\n\n---\n\n### Do parrots actually understand what they are saying?\n\nMost of the time, parrots engage in **contextual association** rather than true language comprehension. For example:\n* A parrot might say "Goodbye!" when it sees you put on your coat because it associates the coat with you leaving.\n* It might say "Hello!" when the phone rings because it hears you do the same.\n\nHowever, some species—especially **African Grey Parrots**—have shown a remarkable capacity to understand concepts. The most famous example, **Alex the African Grey**, was trained by scientist Dr. Irene Pepperberg to correctly identify colors, shapes, materials, and numbers up to six, demonstrating that parrots are capable of using words to communicate real meaning, not just simple mimicry.', 'extras': {'signature': '...'}}], additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-3.6-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019fbe45-768f-7ba2-8534-8683aac5c657-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 6, 'output_tokens': 1657, 'total_tokens': 1663, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 928}})

# %% [markdown]
# GROQ MODEL Integration

# %%
import os
from langchain.chat_models import init_chat_model

os.environ["GROQ_API_KEY"] = os.getenv("GROQ_API_KEY")

model = init_chat_model("groq:llama-3.1-8b-instant")
response = model.invoke("Why do parrots talk?")
response
# Out:
# AIMessage(content='Parrots are known for their ability to mimic human speech and other sounds they hear in their environment. This ability is due to a combination of their unique anatomy, intelligence, and behavior. Here are some reasons why parrots talk:\n\n1. **Mimicry**: Parrots have a highly developed syrinx, which is the vocal organ located at the base of the trachea in birds. The syrinx is made up of two pairs of cartilaginous rings that are covered in muscles and connective tissue. This unique structure allows parrots to produce a wide range of sounds, including human speech.\n2. **Intelligence**: Parrots are considered one of the most intelligent bird species. They have large brains relative to their body size, and they are known for their problem-solving abilities, memory, and communication skills. Their intelligence enables them to learn and mimic complex sounds, including human speech.\n3. **Social behavior**: Parrots are highly social animals that live in flocks in the wild. They use vocalizations to communicate with each other, including warning calls, contact calls, and courtship displays. In captivity, parrots may mimic human speech as a way to interact with their human caregivers and establish a bond.\n4. **Learning and memory**: Parrots have excellent learning and memory abilities. They can learn to mimic sounds by listening to them and then repeating them. They may also use vocalizations to recall specific events or experiences.\n5. **Brain structure**: Research has shown that parrots have a brain structure similar to that of humans, with areas dedicated to language processing. This suggests that parrots may have an innate ability to understand and produce language-like sounds.\n\nSome interesting facts about parrot talking:\n\n* African Greys are considered one of the best talking parrot species, with some individuals reportedly having vocabularies of over 1,000 words.\n* Amazon parrots are also known for their ability to mimic human speech, with some species able to learn up to 300 words.\n* Some parrots can even learn to mimic other sounds, such as car alarms, animal noises, and even musical notes.\n\nOverall, parrots talk due to their unique anatomy, intelligence, social behavior, learning and memory abilities, and brain structure.', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 458, 'prompt_tokens': 41, 'total_tokens': 499, 'completion_time': 0.610504734, 'completion_tokens_details': None, 'prompt_time': 0.002651247, 'prompt_tokens_details': None, 'queue_time': 0.006146167, 'total_time': 0.613155981}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_e2c608b1d6', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019fbe47-ca27-7a33-881c-5d13800b6f37-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 41, 'output_tokens': 458, 'total_tokens': 499})

# %%
import os
from langchain_groq import ChatGroq



model = ChatGroq(model="llama-3.1-8b-instant")
response = model.invoke("Why do parrots talk?")
response
# Out:
# AIMessage(content="Parrots are known for their ability to mimic human speech and other sounds, and it's indeed a fascinating phenomenon. While we can't know for certain why individual parrots talk, scientists have made several discoveries that provide insights into their language abilities.\n\n**Why do parrots talk?**\n\nHere are some possible reasons:\n\n1. **Communication**: Parrots use vocalizations to communicate with each other, just like humans do. They convey information about food, predators, social status, and even emotions. Talking may be a way for them to express themselves and interact with their flock.\n2. **Learning and mimicry**: Parrots are known for their exceptional learning abilities. They can learn to mimic the sounds they hear, including human speech. This is thought to be an adaptation for learning and social bonding, as they may associate the sounds with positive experiences, such as interacting with their owners or finding food.\n3. **Social bonding**: Talking may be a way for parrots to bond with their owners or other birds. By mimicking human speech or other sounds, they may be attempting to connect with others or initiate interactions.\n4. **Attention-seeking**: Some parrots may talk simply because it gets a reaction from their owners or other birds. If they receive attention or treats when they talk, they may learn to repeat the behavior to get what they want.\n5. **Brain structure**: Research suggests that parrots have a unique brain structure that makes them more likely to develop language abilities. Their brains have a large syrinx, a vocal organ located at the base of the trachea, which allows for complex vocalizations.\n\n**How do parrots learn to talk?**\n\nParrots learn to talk by:\n\n1. **Listening**: They listen to the sounds and speech patterns of humans and other birds.\n2. **Imitation**: They practice mimicking the sounds they hear.\n3. **Repetition**: They repeat the sounds and words they've learned to reinforce their understanding.\n4. **Contextual learning**: They associate the sounds with specific situations, such as feeding or interaction.\n\n**Interesting facts**\n\n* Some parrots, like African Greys, are renowned for their ability to learn and mimic human speech.\n* Parrots can learn to mimic over 1,000 words and understand context.\n* Some parrots may even understand the meaning behind certain words or phrases, rather than just mimicking the sounds.\n\nWhile we still don't fully understand the intricacies of parrot language abilities, research continues to uncover the fascinating mechanisms behind their vocalizations and communication behaviors.", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 516, 'prompt_tokens': 41, 'total_tokens': 557, 'completion_time': 1.266843249, 'completion_tokens_details': None, 'prompt_time': 0.003038609, 'prompt_tokens_details': None, 'queue_time': 0.006554424, 'total_time': 1.269881858}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_020e283281', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019fbe49-80a7-7731-931b-505ae522702c-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 41, 'output_tokens': 516, 'total_tokens': 557})

# %% [markdown]
# ### Streaming And Batch

# %% [markdown]
# # Streaming
#
# Most models can stream their output content while it is being generated. By displaying output progressively, streaming significantly improves user experience, particularly for longer responses. Calling stream() returns an iterator that yields output chunks as they are produced. You can use a loop to process each chunk in real-time:

# %%
model.invoke("Write me a 200 words paragraph on Artificial Intelligence")
# Out:
# AIMessage(content='Artificial Intelligence (AI) is a rapidly evolving field of computer science that involves the creation of intelligent machines that can perform tasks that typically require human intelligence, such as learning, problem-solving, and decision-making. AI systems are designed to simulate human thought processes, using algorithms and data analysis to make predictions, classify patterns, and optimize outcomes. The rise of AI has led to numerous breakthroughs in various industries, including healthcare, finance, transportation, and education. AI-powered systems can analyze vast amounts of data, identify trends, and provide insights that humans may miss. They can also automate repetitive tasks, freeing up human resources for more complex and creative work. However, the increasing reliance on AI also raises concerns about job displacement, bias in decision-making, and the potential for AI systems to become autonomous and uncontrollable. Researchers are actively exploring ways to develop more transparent, explainable, and accountable AI systems that can balance the benefits of AI with the need for human oversight and control. As AI continues to advance, it will be crucial to address these challenges and ensure that AI systems are developed and used in ways that benefit both individuals and society as a whole.', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 232, 'prompt_tokens': 45, 'total_tokens': 277, 'completion_time': 0.354037487, 'completion_tokens_details': None, 'prompt_time': 0.049756145, 'prompt_tokens_details': None, 'queue_time': 0.006289552, 'total_time': 0.403793632}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_020e283281', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019fbe4b-2805-7b83-8e74-1c3a1f12a546-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 45, 'output_tokens': 232, 'total_tokens': 277})

# %%
for chunk in model.stream("Write me a 200 words paragraph on Artificial Intelligence"):
    print(chunk.text, end="|", flush=True)
# Out:
# |Art|ificial| Intelligence| (|AI|)| has| emerged| as| a| transformative| technology| that| is| re|def|ining| the| landscape| of| various| industries|,| from| healthcare| and| finance| to| transportation| and| education|.| At| its| core|,| AI| refers| to| the| development| of| computer| systems| that| can| perform| tasks| that| typically| require| human| intelligence|,| such| as| learning|,| problem|-solving|,| and| decision|-making|.| AI| systems| can| be| trained| on| vast| amounts| of| data|,| enabling| them| to| recognize| patterns| and| make| predictions| with| a| high| degree| of| accuracy|.| This| has| led| to| the| creation| of| intelligent| machines| that| can| assist| humans| in| various| tasks|,| from| customer| service| and| data| analysis| to| medical| diagnosis| and| autonomous| driving|.| As| AI| technology| continues| to| advance|,| it| is| expected| to| have| a| profound| impact| on| society|,| creating| new| opportunities| for| economic| growth|,| improving| the| quality| of| life|,| and| enhancing| our| overall| productivity|.| However|,| it| also| raises| important| questions| about| job| displacement|,| data| privacy|,| and| the| ethics| of| AI| development|,| highlighting| the| need| for| careful| consideration| and| regulation| to| ensure| that| the| benefits| of| AI| are| shared| by| all|.| As| AI| continues| to| evolve|,| it| will| be| crucial| to| strike| a| balance| between| its| potential| benefits| and| potential| risks|.|||

# %%
model.invoke("Why do parrots have colorful feathers?")
# Out:
# AIMessage(content="Parrots' colorful feathers serve several purposes:\n\n1. **Mating and Attraction**: Vibrant colors play a significant role in attracting mates and enhancing the species' visibility. Males often display their brightest, most vibrant colors to showcase their health, genetic quality, and ability to provide for a mate.\n2. **Territorial Defense**: Bright plumage serves as a warning signal to potential competitors, signaling that a territory is occupied and defended. This helps parrots establish their dominance and protect their resources.\n3. **Camouflage**: While it may seem counterintuitive, coloration can also aid in camouflage. Some parrots have colors that blend with their surroundings, making it easier for them to hide and escape predators.\n4. **Communication**: Colorful feathers can convey emotional information and intentions. For example, a parrot's bright colors may signal excitement, aggression, or courtship.\n5. **Genetic Expression**: Colorful feathers are often a result of genetic variations that have been favored by natural selection. In some species, bright colors may be a sign of genetic diversity, which is essential for a species' long-term survival.\n6. **Social Signaling**: In some parrot species, coloration is used for social signaling, such as establishing dominance hierarchies or signaling submission.\n\nIt's worth noting that not all parrots are brightly colored. Some species, like the Grey Parrot, have more subdued coloration, which may be an adaptation to their environment or a result of genetic variation.\n\nOverall, the colorful feathers of parrots are a remarkable example of evolutionary adaptation, serving multiple purposes that contribute to their survival and success in their ecosystems.", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 336, 'prompt_tokens': 43, 'total_tokens': 379, 'completion_time': 0.687237326, 'completion_tokens_details': None, 'prompt_time': 0.002268452, 'prompt_tokens_details': None, 'queue_time': 0.00579976, 'total_time': 0.689505778}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_020e283281', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019fbe4b-e683-7641-94c5-faf14fdc4fda-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 43, 'output_tokens': 336, 'total_tokens': 379})

# %%
for chunk in model.stream("Why do parrots have colorful feathers?"):
    print(chunk.text, end="|", flush=True)
# Out:
# |Par|rots| have| colorful| feathers| due| to| the| structure| of| their| feathers| and| the| presence| of| pig|ments|.| Here| are| the| main| reasons|:
#
# |1|.| **|Struct|ural| Color|ation|**:| Par|rots| have| microscopic| crystals| in| their| feathers| that| reflect| light| and| create| a| structural| color| effect|.| This| is| a| physical| phenomenon| where| the| angle| and| spacing| of| the| crystals| cause| the| light| to| scatter| and| reflect|,| producing| a| range| of| colors|.
#
# |2|.| **|P|ig|ment|-based| Color|ation|**:| In| addition| to| structural| color|ation|,| par|rots| have| pig|ments| in| their| feathers| that| contribute| to| their| bright| colors|.| These| pig|ments| are|:
#
# |-| **|Mel|an|in|**:| produces| black|,| brown|,| and| gray| colors|
# |-| **|Car|oten|oids|**:| derived| from| their| diet|,| these| pig|ments| produce| yellow|,| orange|,| and| red| colors|
# |-| **|P|orph|yr|ins|**:| produce| red| and| purple| colors|
#
# |The| combination| of| these| pig|ments| and| structural| color|ation| creates| the| vibrant| colors| we| see| in| par|rots|.
#
# |3|.| **|Ev|olution|ary| Advantage|**:| The| bright| colors| of| par|rots| may| serve| several| purposes|,| such| as|:
#
# |-| **|Communication|**:| par|rots| use| their| colors| to| signal| aggression|,| court|ship|,| or| alarm|
# |-| **|M|ating|**:| males| use| their| bright| colors| to| attract| females|
# |-| **|Cam|ouflage|**:| some| par|rots| have| colors| that| help| them| blend| in| with| their| surroundings|
#
# |The| exact| reason| for| the| colorful| feathers| in| par|rots| is| still| a| topic| of| ongoing| research| and| debate|,| but| it|'s| likely| a| combination| of| these| factors|.
#
# |In| summary|,| par|rots| have| colorful| feathers| due| to| the| combination| of| structural| color|ation|,| pigment|-based| color|ation|,| and| evolutionary| pressures| that| have| shaped| their| appearance| over| time|.|||

# %% [markdown]
# # Batch

# %% [markdown]
# Batching a collection of independent requests to a model can significantly improve performance and reduce costs, as the processing can be done in parallel:

# %%
responses = model.batch([
    "Why do parrots have colorful feathers?",
    "How do airplanes fly?",
    "What is quantum computing?"
])
for response in responses:
    print(response)
# Out:
# content="Parrots have colorful feathers due to the structure and composition of their feathers themselves. The colors and patterns of a parrot's feathers come from microscopic structures within the feather that scatter light in different ways.\n\nThere are two main types of structures that contribute to the colors of a parrot's feathers:\n\n1. **Melanin**: Melanin is a pigment produced by cells in the feather called melanocytes. There are two types of melanin: eumelanin, which produces black and dark brown colors, and pheomelanin, which produces red and yellow colors. By varying the amounts and combinations of these melanins, parrots can produce a wide range of colors.\n2. **Iridescence**: Iridescence is a phenomenon where light is scattered by the microscopic structure of the feather, creating colors that change depending on the angle of view. This is achieved through the presence of tiny platelets called melanosomes, which contain melanin. The shape and arrangement of these melanosomes can create a range of colors, including blues, greens, and golds.\n\nWhen light hits a parrot's feather, it encounters the microscopic structures within the feather, which scatter the light in different ways, creating the colors we see. The combination of melanin and iridescence allows parrots to display a wide range of colors, which play an important role in their behavior, communication, and mating rituals.\n\nIn addition to their functional importance, the colorful feathers of parrots also serve as an adaptation to their environment. For example, bright colors can help parrots attract a mate, signal their fitness and health, or warn off predators.\n\nOverall, the colorful feathers of parrots are a remarkable example of the intricate relationships between structure, biology, and environment that govern the natural world." additional_kwargs={} response_metadata={'token_usage': {'completion_tokens': 365, 'prompt_tokens': 43, 'total_tokens': 408, 'completion_time': 0.684156615, 'completion_tokens_details': None, 'prompt_time': 0.02652313, 'prompt_tokens_details': None, 'queue_time': 0.005258714, 'total_time': 0.710679745}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_020e283281', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'} id='lc_run--019fbe4e-703d-7751-bd20-975e311ce1b0-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 43, 'output_tokens': 365, 'total_tokens': 408}
# content="Airplanes fly by using the four fundamental forces of nature: lift, weight, thrust, and drag. Here's a simplified explanation of how it works:\n\n1. **Lift**: Lift is the upward force that opposes the weight of the airplane and keeps it flying. It's created by the shape of the wings, which are designed to produce a difference in air pressure above and below the wing. As the airplane moves forward, the air flows over and under the curved surface of the wing, creating an area of lower pressure above the wing and an area of higher pressure below it. This pressure difference creates an upward force called lift, which counteracts the weight of the airplane.\n\n2. **Weight**: Weight is the downward force that pulls the airplane towards the ground. It's the combined weight of the airplane, passengers, cargo, and fuel.\n\n3. **Thrust**: Thrust is the forward force that propels the airplane through the air. It's created by the airplane's engines, which produce a stream of high-speed air that exits the rear of the airplane. As this air exits, it produces a forward force that propels the airplane forward.\n\n4. **Drag**: Drag is the backward force that slows the airplane down. It's created by the air resistance that the airplane encounters as it moves through the air.\n\nTo generate lift, thrust, and control the drag, airplanes use several key components:\n\n- **Wings**: The shape and angle of attack of the wings determine the amount of lift generated.\n- **Engines**: The engines provide thrust by accelerating a large mass of air rearward.\n- **Control surfaces**: The ailerons, elevator, and rudder are control surfaces that are used to control the direction and attitude of the airplane.\n- **Airfoil**: The curved upper surface of the wing is called the airfoil. It helps to create the pressure difference between the upper and lower surfaces, resulting in lift.\n\nWhen an airplane is in flight, the lift and thrust forces are in balance, and the airplane is able to fly steadily. However, to control the airplane's direction and attitude, the pilot must use the control surfaces to adjust the amount of lift and drag.\n\nHere's a step-by-step summary of how an airplane flies:\n\n1. The airplane accelerates down the runway, building up speed.\n2. As the airplane reaches a certain speed, the wings begin to produce lift, and the airplane starts to rise into the air.\n3. Once airborne, the engines provide thrust to propel the airplane forward.\n4. The control surfaces (ailerons, elevator, and rudder) are used to control the direction and attitude of the airplane.\n5. As the airplane flies, the lift and thrust forces are in balance, and the airplane is able to fly steadily.\n6. To descend or change direction, the pilot adjusts the control surfaces to change the amount of lift and drag.\n\nThis simplified explanation provides a basic understanding of how airplanes fly. However, the actual mechanics of flight are much more complex and involve many other factors, such as airflow, air pressure, and wing design." additional_kwargs={} response_metadata={'token_usage': {'completion_tokens': 628, 'prompt_tokens': 40, 'total_tokens': 668, 'completion_time': 1.106193674, 'completion_tokens_details': None, 'prompt_time': 0.001846119, 'prompt_tokens_details': None, 'queue_time': 0.005278558, 'total_time': 1.108039793}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_020e283281', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'} id='lc_run--019fbe4e-703e-7a93-9714-73e2ee57bb1c-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 40, 'output_tokens': 628, 'total_tokens': 668}
# content='Quantum computing is a new and exciting field of computer science that uses the principles of quantum mechanics to perform calculations and operations on data. It\'s a fundamentally different approach to computing than classical computing, which is based on the principles of classical physics.\n\n**Classical Computing vs. Quantum Computing**\n\nClassical computers use "bits" to store and process information. Each bit can have a value of either 0 or 1, and these bits are used to represent data and perform calculations. However, this binary system has limitations, especially when dealing with complex problems that require processing multiple possibilities simultaneously.\n\nQuantum computers, on the other hand, use "qubits" (quantum bits) to store and process information. Qubits are unique because they can exist in multiple states at the same time, known as a superposition. This allows quantum computers to process multiple possibilities simultaneously, making them potentially much faster than classical computers for certain types of calculations.\n\n**Key Principles of Quantum Computing**\n\n1. **Superposition**: Qubits can exist in multiple states at the same time, allowing for parallel processing of multiple possibilities.\n2. **Entanglement**: Qubits can be connected in such a way that the state of one qubit is dependent on the state of the other, even if they are separated by large distances.\n3. **Quantum measurement**: When a qubit is measured, its state collapses to one of the possible states, much like flipping a coin and getting either heads or tails.\n4. **Quantum gates**: These are the quantum equivalent of logic gates in classical computing, used to manipulate qubits and perform operations on them.\n\n**Applications of Quantum Computing**\n\n1. **Cryptography**: Quantum computers can potentially break certain types of classical encryption, but they can also be used to create unbreakable quantum encryption.\n2. **Optimization**: Quantum computers can quickly solve complex optimization problems, such as finding the shortest path in a network or the most efficient way to allocate resources.\n3. **Simulation**: Quantum computers can simulate complex systems, such as molecules and materials, which can lead to breakthroughs in fields like chemistry and materials science.\n4. **Machine learning**: Quantum computers can be used to speed up certain types of machine learning algorithms, such as those used in image and speech recognition.\n\n**Challenges and Limitations**\n\n1. **Noise and error correction**: Quantum computers are prone to errors due to the noisy nature of quantum systems. Developing robust error correction techniques is an active area of research.\n2. **Scalability**: Currently, quantum computers are small-scale and require complex machinery to operate. Scaling up to larger, more practical systems is a significant challenge.\n3. **Quantum control**: Maintaining control over the quantum states of qubits is essential, but this becomes increasingly difficult as the number of qubits increases.\n\nIn summary, quantum computing is a new and exciting field that has the potential to revolutionize many areas of science and engineering. While there are significant challenges and limitations to overcome, the possibilities are vast and intriguing.' additional_kwargs={} response_metadata={'token_usage': {'completion_tokens': 614, 'prompt_tokens': 40, 'total_tokens': 654, 'completion_time': 0.74597417, 'completion_tokens_details': None, 'prompt_time': 0.002138451, 'prompt_tokens_details': None, 'queue_time': 0.005710651, 'total_time': 0.748112621}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_e2c608b1d6', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'} id='lc_run--019fbe4e-703f-7680-851b-f870df17dd3b-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 40, 'output_tokens': 614, 'total_tokens': 654}

# %%
model.batch(
    ["Why do parrots have colorful feathers?",
    "How do airplanes fly?",
    "What is quantum computing?"],
    config={
        'max_concurrency': 5,  # Limit to 5 parallel calls
    }
)
# Out:
# [AIMessage(content="Parrots have colorful feathers due to several reasons, including:\n\n1. **Attracting mates**: Bright colors help parrots attract potential mates, as they signal good health, genetic quality, and reproductive fitness. The more vibrant and extensive the coloration, the more attractive the parrot is to potential mates.\n2. **Communication and social status**: Colorful feathers help parrots communicate their social status, dominance, or submission. They can also signal aggression, courtship, or other social intentions.\n3. **Thermoregulation**: Dark colors can absorb heat, while light colors can reflect it. This helps parrots regulate their body temperature in various environments.\n4. **Camouflage and protection**: Some parrot species have camouflage colors that help them blend in with their surroundings, making it harder for predators to spot them. On the other hand, brighter colors can also serve as a warning signal to potential predators.\n5. **Evolutionary adaptations**: Over time, certain color patterns and combinations have become more advantageous for parrot species, allowing them to adapt to their environments and survive better.\n6. **Sexual dimorphism**: Some parrot species exhibit sexual dimorphism, where males and females have different coloration patterns. This helps in distinguishing between the sexes.\n\nThe colors in a parrot's feathers come from various sources:\n\n* **Melanin**: This pigment is responsible for brown and black colors in parrots.\n* **Carotenoids**: These pigments, derived from the parrot's diet, produce yellow, orange, and red colors.\n* **Porphyrins**: These pigments, similar to carotenoids, contribute to red and orange colors.\n* **Iridescence**: Some parrot feathers display iridescence, caused by the way microscopic structures refract light, creating shimmering, rainbow-like effects.\n\nThese factors combined create the stunning color palette we see in parrots, making them one of the most visually striking bird groups in the world.", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 403, 'prompt_tokens': 43, 'total_tokens': 446, 'completion_time': 0.814813524, 'completion_tokens_details': None, 'prompt_time': 0.003664228, 'prompt_tokens_details': None, 'queue_time': 0.006228858, 'total_time': 0.818477752}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_020e283281', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019fbe4e-d916-7620-9173-6e65f36e2ae5-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 43, 'output_tokens': 403, 'total_tokens': 446}),
#  AIMessage(content="Airplanes fly by using four fundamental forces of physics: lift, weight, thrust, and drag. \n\n1. **Lift**: Lift is the upward force that opposes the weight of the airplane and keeps it flying. It is created by the shape of the wings, which are designed to produce a difference in air pressure above and below the wing. As the airplane moves forward, the air flowing over the curved upper surface of the wing must travel faster than the air flowing along the flat lower surface. This creates a region of lower air pressure above the wing and a region of higher air pressure below it, resulting in an upward force called lift.\n\n2. **Weight**: Weight is the downward force that pulls the airplane towards the ground. It is equal to the mass of the airplane multiplied by the acceleration due to gravity.\n\n3. **Thrust**: Thrust is the forward force that propels the airplane through the air. It is created by the airplane's engines, which produce a stream of high-speed air that exits the back of the plane. This stream of air creates a forward force that counteracts the drag, or resistance, created by the air.\n\n4. **Drag**: Drag is the backward force that opposes the motion of the airplane. It is created by the air resistance that the airplane encounters as it moves forward.\n\nWhen an airplane is in flight, the lift and weight forces are in balance, and the thrust and drag forces are in balance. The lift force must be greater than the weight force for the airplane to fly, and the thrust force must be greater than the drag force for the airplane to move forward.\n\nHere's a step-by-step explanation of how an airplane flies:\n\n- The airplane moves forward, creating a stream of air that flows over and under the wing.\n- The air flowing over the curved upper surface of the wing must travel faster than the air flowing along the flat lower surface, creating a pressure difference.\n- The pressure difference creates an upward force called lift, which opposes the weight of the airplane.\n- The engines produce a forward force called thrust, which counteracts the drag created by the air.\n- The lift and weight forces are in balance, and the thrust and drag forces are in balance, allowing the airplane to fly steadily.\n\nIn summary, airplanes fly by using the shape of the wings to create lift, the engines to produce thrust, and the balance of forces to maintain steady flight.", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 487, 'prompt_tokens': 40, 'total_tokens': 527, 'completion_time': 0.648896554, 'completion_tokens_details': None, 'prompt_time': 0.00350617, 'prompt_tokens_details': None, 'queue_time': 0.00681769, 'total_time': 0.652402724}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_020e283281', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019fbe4e-d917-7193-9e83-6d9ff1f3f9bf-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 40, 'output_tokens': 487, 'total_tokens': 527}),
#  AIMessage(content="Quantum computing is a new and rapidly evolving field of computer science that uses the principles of quantum mechanics to perform computations. It's based on the idea of using quantum-mechanical phenomena, such as superposition and entanglement, to represent and process information in a fundamentally different way than classical computers.\n\n**What's wrong with classical computing?**\n\nClassical computers use bits, which can only be in one of two states: 0 or 1. This binary system allows for efficient processing, but it's limited by the fact that it can only process information one bit at a time. As the number of bits increases, the number of possible combinations grows exponentially, leading to a rapid increase in computational time and power requirements.\n\n**How does quantum computing work?**\n\nQuantum computers use quantum bits, or qubits, which can exist in multiple states simultaneously. This is known as a superposition. Qubits can represent a mixture of 0 and 1, as well as any other possible value, all at the same time. This property allows quantum computers to process multiple possibilities simultaneously, making them potentially much faster than classical computers for certain types of calculations.\n\nAnother key feature of quantum computing is entanglement, which is the ability of qubits to become connected in such a way that the state of one qubit is dependent on the state of the other, even if they are separated by large distances. This allows quantum computers to perform calculations on multiple qubits at the same time, which can lead to exponential speedup over classical computers.\n\n**Quantum computing applications**\n\nQuantum computing has the potential to revolutionize many fields, including:\n\n1. **Cryptography**: Quantum computers can potentially break many classical encryption algorithms, but they can also be used to create new, quantum-resistant encryption methods.\n2. **Optimization**: Quantum computers can solve complex optimization problems much faster than classical computers, which can lead to breakthroughs in fields like logistics, finance, and energy management.\n3. **Simulation**: Quantum computers can simulate complex systems, such as molecules and chemical reactions, which can lead to breakthroughs in fields like chemistry and materials science.\n4. **Machine learning**: Quantum computers can be used to speed up machine learning algorithms, which can lead to breakthroughs in fields like image recognition and natural language processing.\n\n**Challenges and limitations**\n\nWhile quantum computing has the potential to revolutionize many fields, it's still a developing technology, and there are many challenges and limitations to overcome. Some of these include:\n\n1. **Error correction**: Quantum computers are prone to errors due to the fragile nature of qubits. Developing robust error correction methods is essential for large-scale quantum computing.\n2. **Scalability**: Currently, most quantum computers are small-scale and can only perform a limited number of operations. Scaling up to larger systems is a significant challenge.\n3. **Quantum noise**: Quantum computers are susceptible to noise, which can cause errors and affect the accuracy of calculations.\n4. **Quantum control**: Maintaining control over qubits and ensuring that they operate as predicted is a significant challenge.\n\nIn summary, quantum computing is a new and rapidly evolving field that uses the principles of quantum mechanics to perform computations. While it has the potential to revolutionize many fields, it's still a developing technology, and there are many challenges and limitations to overcome.", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 675, 'prompt_tokens': 40, 'total_tokens': 715, 'completion_time': 1.03404613, 'completion_tokens_details': None, 'prompt_time': 0.003324133, 'prompt_tokens_details': None, 'queue_time': 0.007056017, 'total_time': 1.037370263} ...
